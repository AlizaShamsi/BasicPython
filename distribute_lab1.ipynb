# %% [markdown]
# <a href="https://colab.research.google.com/github/AlizaShamsi/BasicPython/blob/main/distribute_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 1: Dictionaries and Classes

# %% [markdown]
# ## EXERCISE 1: Count words in Julius Caesar and make a text based histogram
#
# Building on the first lab, using lowercase words, lets make a histogram. Create a dictionary `worddict`, that has the counts of all the words in Caesar.

# %%
# your code here
# !wget "https://raw.githubusercontent.com/AlizaShamsi/BasicPython/main/data/Julius%20Caesar.txt"
# Out:
# --2020-12-29 13:40:08--  https://raw.githubusercontent.com/AlizaShamsi/BasicPython/main/data/Julius%20Caesar.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 120873 (118K) [text/plain]
# Saving to: ‘Julius Caesar.txt.4’
#
# Julius Caesar.txt.4 100%[===================>] 118.04K  --.-KB/s    in 0.01s
#
# 2020-12-29 13:40:08 (8.66 MB/s) - ‘Julius Caesar.txt.4’ saved [120873/120873]

# %%
 
fd=open("Julius Caesar.txt")
worddict=dict()
for line in fd.readlines():
   line.strip()
   words=line.split()
   for word in words:
     if word in worddict.keys():
       worddict[word]+=1
     else:
       worddict[word]=1
worddict
# Out:
# {'THE': 1,
#  'TRAGEDY': 1,
#  'OF': 1,
#  'JULIUS': 2,
#  'CAESAR': 2,
#  'by': 80,
#  'William': 1,
#  'Shakespeare': 1,
#  'Contents': 1,
#  'ACT': 10,
#  'I': 499,
#  'Scene': 18,
#  'I.': 13,
#  'Rome.': 13,
#  'A': 44,
#  'street.': 6,
#  'II.': 10,
#  'The': 97,
#  'same.': 10,
#  'public': 5,
#  'place.': 5,
#  'III.': 10,
#  'II': 2,
#  'Brutusâ€™': 13,
#  'orchard.': 2,
#  'room': 6,
#  'in': 206,
#  'Caesarâ€™s': 40,
#  'palace.': 2,
#  'street': 5,
#  'near': 10,
#  'the': 531,
#  'Capitol.': 9,
#  'IV.': 4,
#  'Another': 10,
#  'part': 13,
#  'of': 356,
#  'same': 7,
#  'street,': 2,
#  'before': 10,
#  'house': 6,
#  'Brutus.': 22,
#  'III': 2,
#  'Before': 6,
#  'Capitol;': 5,
#  'Senate': 5,
#  'sitting.': 2,
#  'Forum.': 2,
#  'IV': 2,
#  'Antonyâ€™s': 2,
#  'house.': 5,
#  'tent,': 4,
#  'camp': 3,
#  'Sardis.': 2,
#  'Within': 4,
#  'tent': 6,
#  'V': 2,
#  'plains': 3,
#  'Philippi.': 7,
#  'field': 3,
#  'battle.': 2,
#  'field.': 10,
#  'V.': 2,
#  'Dramatis': 1,
#  'PersonÃ¦': 1,
#  'OCTAVIUS': 1,
#  'CAESAR,': 1,
#  'Triumvir': 1,
#  'after': 10,
#  'his': 150,
#  'death.': 11,
#  'MARCUS': 2,
#  'ANTONIUS,': 1,
#  'â€\x9d': 26,
#  'M.': 1,
#  'AEMILIUS': 1,
#  'LEPIDUS,': 1,
#  'CICERO,': 1,
#  'PUBLIUS,': 1,
#  'POPILIUS': 1,
#  'LENA,': 1,
#  'Senators.': 2,
#  'BRUTUS,': 2,
#  'Conspirator': 1,
#  'against': 8,
#  'Caesar.': 21,
#  'CASSIUS,': 1,
#  'CASCA,': 1,
#  'TREBONIUS,': 1,
#  'LIGARIUS,â€\x9d': 1,
#  'DECIUS': 1,
#  'METELLUS': 1,
#  'CIMBER,': 1,
#  'CINNA,': 2,
#  'FLAVIUS,': 1,
#  'tribune': 2,
#  'MARULLUS,': 1,
#  'ARTEMIDORUS,': 1,
#  'a': 231,
#  'Sophist': 1,
#  'Cnidos.': 1,
#  'Soothsayer': 1,
#  'poet.': 2,
#  'Poet.': 1,
#  'LUCILIUS,': 1,
#  'TITINIUS,': 1,
#  'MESSALA,': 1,
#  'young': 11,
#  'CATO,': 1,
#  'and': 426,
#  'VOLUMNIUS,': 1,
#  'Friends': 2,
#  'to': 347,
#  'Brutus': 69,
#  'Cassius.': 12,
#  'VARRO,': 1,
#  'CLITUS,': 1,
#  'CLAUDIUS,': 1,
#  'STRATO,': 1,
#  'LUCIUS,': 1,
#  'DARDANIUS,': 1,
#  'Servants': 1,
#  'PINDARUS,': 1,
#  'Servant': 1,
#  'Cassius': 25,
#  'CALPHURNIA,': 1,
#  'wife': 3,
#  'Caesar': 94,
#  'PORTIA,': 1,
#  'Ghost': 2,
#  'Senators,': 4,
#  'Citizens,': 2,
#  'Soldiers,': 1,
#  'Commoners,': 1,
#  'Messengers,': 1,
#  'Servants.': 1,
#  'SCENE:': 1,
#  'Rome,': 15,
#  'conspiratorsâ€™': 1,
#  'Sardis,': 2,
#  'SCENE': 18,
#  'Enter': 54,
#  'Flavius,': 3,
#  'Marullus': 2,
#  'throng': 3,
#  'Citizens.': 3,
#  'FLAVIUS.': 5,
#  'Hence!': 3,
#  'home,': 1,
#  'you': 265,
#  'idle': 3,
#  'creatures,': 1,
#  'get': 8,
#  'home.': 3,
#  'Is': 22,
#  'this': 119,
#  'holiday?': 2,
#  'What,': 15,
#  'know': 57,
#  'not,': 23,
#  'Being': 3,
#  'mechanical,': 1,
#  'ought': 2,
#  'not': 199,
#  'walk': 7,
#  'Upon': 12,
#  'labouring': 1,
#  'day': 15,
#  'without': 4,
#  'sign': 4,
#  'Of': 17,
#  'your': 121,
#  'profession?': 1,
#  'Speak,': 3,
#  'what': 56,
#  'trade': 3,
#  'art': 19,
#  'thou?': 4,
#  'CARPENTER.': 1,
#  'Why,': 18,
#  'sir,': 16,
#  'carpenter.': 1,
#  'MARULLUS.': 6,
#  'Where': 15,
#  'is': 214,
#  'thy': 44,
#  'leather': 2,
#  'apron': 1,
#  'rule?': 1,
#  'What': 50,
#  'dost': 8,
#  'thou': 95,
#  'with': 137,
#  'best': 11,
#  'apparel': 1,
#  'on?': 2,
#  'You,': 1,
#  'are': 90,
#  'you?': 8,
#  'COBBLER.': 6,
#  'Truly,': 4,
#  'respect': 6,
#  'fine': 1,
#  'workman,': 1,
#  'am': 50,
#  'but,': 8,
#  'as': 102,
#  'would': 40,
#  'say,': 6,
#  'cobbler.': 1,
#  'But': 61,
#  'Answer': 2,
#  'me': 120,
#  'directly.': 4,
#  'trade,': 2,
#  'that': 184,
#  'hope': 1,
#  'may': 30,
#  'use': 7,
#  'safe': 2,
#  'conscience,': 1,
#  'which': 22,
#  'indeed,': 5,
#  'mender': 1,
#  'bad': 8,
#  'soles.': 1,
#  'knave?': 1,
#  'Thou': 12,
#  'naughty': 1,
#  'knave,': 3,
#  'trade?': 1,
#  'Nay,': 5,
#  'beseech': 3,
#  'you,': 33,
#  'be': 129,
#  'out': 13,
#  'me;': 6,
#  'yet,': 3,
#  'if': 32,
#  'out,': 8,
#  'can': 18,
#  'mend': 1,
#  'you.': 22,
#  'meanâ€™st': 1,
#  'that?': 5,
#  'Mend': 1,
#  'me,': 35,
#  'saucy': 2,
#  'fellow!': 1,
#  'cobble': 1,
#  'cobbler,': 1,
#  'all': 79,
#  'live': 5,
#  'awl;': 1,
#  'meddle': 1,
#  'no': 65,
#  'tradesmanâ€™s': 1,
#  'matters,': 2,
#  'nor': 14,
#  'womenâ€™s': 1,
#  'but': 65,
#  'withal': 4,
#  'surgeon': 1,
#  'old': 4,
#  'shoes:': 1,
#  'when': 39,
#  'they': 44,
#  'great': 25,
#  'danger,': 1,
#  'recover': 1,
#  'them.': 9,
#  'As': 33,
#  'proper': 3,
#  'men': 35,
#  'ever': 12,
#  'trod': 1,
#  'upon': 32,
#  'neatâ€™s': 1,
#  'have': 125,
#  'gone': 3,
#  'my': 169,
#  'handiwork.': 1,
#  'wherefore': 3,
#  'shop': 1,
#  'today?': 1,
#  'Why': 18,
#  'lead': 6,
#  'these': 30,
#  'about': 15,
#  'streets?': 1,
#  'wear': 4,
#  'their': 59,
#  'shoes,': 1,
#  'myself': 10,
#  'into': 10,
#  'more': 24,
#  'work.': 2,
#  'we': 80,
#  'make': 20,
#  'holiday': 1,
#  'see': 27,
#  'Caesar,': 40,
#  'rejoice': 2,
#  'triumph.': 1,
#  'Wherefore': 3,
#  'rejoice?': 1,
#  'conquest': 3,
#  'brings': 3,
#  'he': 135,
#  'home?': 2,
#  'tributaries': 1,
#  'follow': 9,
#  'him': 90,
#  'To': 75,
#  'grace': 4,
#  'captive': 1,
#  'bonds': 1,
#  'chariot': 2,
#  'wheels?': 1,
#  'You': 47,
#  'blocks,': 1,
#  'stones,': 2,
#  'worse': 3,
#  'than': 33,
#  'senseless': 1,
#  'things!': 1,
#  'O': 48,
#  'hard': 4,
#  'hearts,': 3,
#  'cruel': 2,
#  'Knew': 1,
#  'Pompey?': 1,
#  'Many': 1,
#  'time': 18,
#  'oft': 3,
#  'Have': 19,
#  'climbâ€™d': 1,
#  'up': 26,
#  'walls': 3,
#  'battlements,': 1,
#  'towers': 1,
#  'windows,': 2,
#  'yea,': 2,
#  'chimney': 1,
#  'tops,': 1,
#  'Your': 12,
#  'infants': 2,
#  'arms,': 2,
#  'there': 25,
#  'sat': 1,
#  'livelong': 1,
#  'patient': 3,
#  'expectation,': 1,
#  'Pompey': 2,
#  'pass': 5,
#  'streets': 3,
#  'And': 201,
#  'saw': 7,
#  'appear,': 2,
#  'made': 10,
#  'an': 30,
#  'universal': 1,
#  'shout,': 1,
#  'That': 85,
#  'Tiber': 4,
#  'trembled': 1,
#  'underneath': 2,
#  'her': 9,
#  'banks': 1,
#  'hear': 27,
#  'replication': 1,
#  'sounds': 1,
#  'Made': 1,
#  'concave': 1,
#  'shores?': 1,
#  'do': 104,
#  'now': 21,
#  'put': 15,
#  'on': 63,
#  'attire?': 1,
#  'cull': 1,
#  'strew': 1,
#  'flowers': 1,
#  'way,': 3,
#  'comes': 14,
#  'triumph': 3,
#  'over': 4,
#  'Pompeyâ€™s': 6,
#  'blood?': 1,
#  'Be': 15,
#  'gone!': 2,
#  'Run': 3,
#  'houses,': 1,
#  'fall': 6,
#  'knees,': 2,
#  'Pray': 1,
#  'gods': 9,
#  'intermit': 1,
#  'plague': 1,
#  'needs': 1,
#  'must': 30,
#  'light': 3,
#  'ingratitude.': 1,
#  'Go,': 3,
#  'go,': 3,
#  'good': 42,
#  'countrymen,': 6,
#  'and,': 8,
#  'for': 116,
#  'fault': 2,
#  'Assemble': 1,
#  'poor': 7,
#  'sort,': 1,
#  'Draw': 1,
#  'them': 37,
#  'banks,': 1,
#  'weep': 4,
#  'tears': 2,
#  'Into': 5,
#  'channel,': 1,
#  'till': 20,
#  'lowest': 1,
#  'stream': 2,
#  'Do': 14,
#  'kiss': 3,
#  'most': 19,
#  'exalted': 2,
#  'shores': 1,
#  'all.': 5,
#  '[_Exeunt': 11,
#  'Citizens._]': 1,
#  'See': 3,
#  'whether': 4,
#  'basest': 1,
#  'metal': 2,
#  'movâ€™d;': 1,
#  'They': 18,
#  'vanish': 1,
#  'tongue-tied': 1,
#  'guiltiness.': 1,
#  'Go': 8,
#  'down': 11,
#  'way': 7,
#  'towards': 2,
#  'This': 23,
#  'will': 117,
#  'Disrobe': 1,
#  'images,': 2,
#  'If': 52,
#  'find': 17,
#  'deckâ€™d': 1,
#  'ceremonies.': 3,
#  'May': 3,
#  'so?': 7,
#  'it': 122,
#  'feast': 2,
#  'Lupercal.': 1,
#  'It': 31,
#  'matter;': 2,
#  'let': 38,
#  'images': 1,
#  'hung': 2,
#  'trophies.': 1,
#  'Iâ€™ll': 13,
#  'drive': 1,
#  'away': 4,
#  'vulgar': 1,
#  'from': 46,
#  'streets;': 2,
#  'So': 31,
#  'too,': 3,
#  'where': 11,
#  'perceive': 5,
#  'thick.': 2,
#  'These': 6,
#  'growing': 2,
#  'feathers': 1,
#  'pluckâ€™d': 4,
#  'wing': 1,
#  'Will': 15,
#  'fly': 3,
#  'ordinary': 3,
#  'pitch,': 1,
#  'Who': 15,
#  'else': 9,
#  'soar': 1,
#  'above': 2,
#  'view': 1,
#  'men,': 14,
#  'keep': 8,
#  'us': 43,
#  'servile': 1,
#  'fearfulness.': 1,
#  '[_Exeunt._]': 15,
#  'Enter,': 2,
#  'procession,': 1,
#  'music,': 2,
#  'Caesar;': 10,
#  'Antony,': 22,
#  'course;': 1,
#  'Calphurnia,': 1,
#  'Portia,': 5,
#  'Decius,': 5,
#  'Cicero,': 2,
#  'Brutus,': 50,
#  'Casca;': 4,
#  'crowd': 3,
#  'following,': 1,
#  'among': 2,
#  'Soothsayer.': 3,
#  'CAESAR.': 40,
#  'Calphurnia.': 3,
#  'CASCA.': 40,
#  'Peace,': 6,
#  'ho!': 17,
#  'speaks.': 2,
#  '[_Music': 2,
#  'ceases._]': 2,
#  'CALPHURNIA.': 6,
#  'Here,': 6,
#  'lord.': 16,
#  'Stand': 8,
#  'directly': 4,
#  'Antoniusâ€™': 1,
#  'When': 26,
#  'doth': 25,
#  'run': 9,
#  'course.': 1,
#  'Antonius.': 2,
#  'ANTONY.': 51,
#  'lord?': 12,
#  'Forget': 1,
#  'speed,': 2,
#  'Antonius,': 1,
#  'touch': 2,
#  'Calphurnia;': 1,
#  'our': 74,
#  'elders': 1,
#  'barren,': 1,
#  'touched': 1,
#  'holy': 2,
#  'chase,': 1,
#  'Shake': 1,
#  'off': 10,
#  'sterile': 1,
#  'curse.': 1,
#  'shall': 106,
#  'remember.': 1,
#  'says': 8,
#  'â€œDo': 1,
#  'this,â€\x9d': 1,
#  'performâ€™d.': 1,
#  'Set': 6,
#  'on;': 2,
#  'leave': 15,
#  'ceremony': 1,
#  'out.': 3,
#  '[_Music._]': 1,
#  'SOOTHSAYER.': 9,
#  'Caesar!': 11,
#  'Ha!': 2,
#  'calls?': 1,
#  'Bid': 5,
#  'every': 23,
#  'noise': 4,
#  'still;': 2,
#  'peace': 2,
#  'yet': 22,
#  'again!': 1,
#  'press': 5,
#  'calls': 1,
#  'me?': 7,
#  'tongue': 5,
#  'shriller': 1,
#  'Cry': 3,
#  'â€œCaesarâ€\x9d!': 1,
#  'Speak.': 1,
#  'turnâ€™d': 3,
#  'hear.': 2,
#  'Beware': 2,
#  'Ides': 7,
#  'March.': 3,
#  'man': 35,
#  'BRUTUS.': 193,
#  'soothsayer': 1,
#  'bids': 2,
#  'beware': 2,
#  'face.': 1,
#  'CASSIUS.': 138,
#  'Fellow,': 2,
#  'come': 37,
#  'throng;': 1,
#  'look': 15,
#  'sayâ€™st': 1,
#  'now?': 2,
#  'Speak': 7,
#  'once': 5,
#  'again.': 3,
#  'He': 50,
#  'dreamer;': 1,
#  'him.': 28,
#  'Pass.': 1,
#  '[_Sennet.': 1,
#  'Exeunt': 1,
#  'Cassius._]': 2,
#  'go': 28,
#  'order': 3,
#  'course?': 1,
#  'Not': 8,
#  'pray': 5,
#  'do.': 4,
#  'gamesome:': 1,
#  'lack': 1,
#  'some': 37,
#  'quick': 2,
#  'spirit': 8,
#  'Antony.': 20,
#  'Let': 25,
#  'hinder,': 1,
#  'Cassius,': 34,
#  'desires;': 1,
#  'observe': 2,
#  'late:': 1,
#  'eyes': 8,
#  'gentleness': 1,
#  'show': 11,
#  'love': 27,
#  'was': 58,
#  'wont': 1,
#  'have.': 1,
#  'bear': 19,
#  'too': 15,
#  'stubborn': 1,
#  'strange': 6,
#  'hand': 11,
#  'Over': 2,
#  'friend': 9,
#  'loves': 6,
#  'deceived:': 1,
#  'veilâ€™d': 1,
#  'look,': 6,
#  'turn': 8,
#  'trouble': 3,
#  'countenance': 1,
#  'Merely': 1,
#  'myself.': 4,
#  'Vexed': 1,
#  'late': 1,
#  'passions': 1,
#  'difference,': 1,
#  'Conceptions': 1,
#  'only': 6,
#  'myself,': 3,
#  'Which': 20,
#  'give': 22,
#  'soil': 1,
#  'perhaps': 1,
#  'behaviors;': 1,
#  'therefore': 5,
#  'friends': 4,
#  'grieved': 1,
#  '(Among': 1,
#  'number,': 1,
#  'one)': 1,
#  'Nor': 10,
#  'construe': 3,
#  'any': 13,
#  'further': 4,
#  'neglect,': 1,
#  'Than': 9,
#  'himself': 6,
#  'at': 58,
#  'war,': 3,
#  'Forgets': 1,
#  'shows': 2,
#  'other': 12,
#  'men.': 6,
#  'Then,': 5,
#  'much': 24,
#  'mistook': 1,
#  'passion;': 1,
#  'By': 17,
#  'means': 6,
#  'whereof': 1,
#  'breast': 2,
#  'mine': 19,
#  'hath': 29,
#  'buried': 3,
#  'Thoughts': 1,
#  'value,': 1,
#  'worthy': 8,
#  'cogitations.': 1,
#  'Tell': 6,
#  'face?': 1,
#  'No,': 17,
#  'eye': 5,
#  'sees': 2,
#  'itself': 2,
#  'reflection,': 2,
#  'thing.': 1,
#  'â€™Tis': 9,
#  'just:': 1,
#  'very': 12,
#  'lamented,': 1,
#  'such': 30,
#  'mirrors': 1,
#  'hidden': 1,
#  'worthiness': 1,
#  'eye,': 1,
#  'might': 10,
#  'shadow.': 1,
#  'heard': 7,
#  'many': 14,
#  '(Except': 1,
#  'immortal': 2,
#  'Caesar)': 1,
#  'speaking': 2,
#  'groaning': 2,
#  'ageâ€™s': 1,
#  'yoke,': 1,
#  'wishâ€™d': 2,
#  'noble': 34,
#  'had': 22,
#  'eyes.': 2,
#  'dangers': 3,
#  'seek': 5,
#  'For': 52,
#  'Therefore,': 1,
#  'prepared': 1,
#  'hear;': 2,
#  'since': 5,
#  'cannot': 5,
#  'yourself': 8,
#  'well': 29,
#  'I,': 11,
#  'glass,': 1,
#  'modestly': 1,
#  'discover': 2,
#  'of.': 3,
#  'jealous': 1,
#  'gentle': 8,
#  'Brutus:': 1,
#  'Were': 1,
#  'common': 9,
#  'laugher,': 1,
#  'or': 36,
#  'did': 58,
#  'stale': 1,
#  'oaths': 1,
#  'new': 3,
#  'protester;': 1,
#  'fawn': 2,
#  'hug': 1,
#  'hard,': 4,
#  'scandal': 1,
#  'them;': 3,
#  'profess': 1,
#  'banqueting,': 1,
#  'rout,': 1,
#  'then': 32,
#  'hold': 10,
#  'dangerous.': 4,
#  '[_Flourish': 1,
#  'shout._]': 1,
#  'shouting?': 1,
#  'fear': 20,
#  'people': 9,
#  'Choose': 1,
#  'king.': 2,
#  'Ay,': 14,
#  'it?': 4,
#  'Then': 12,
#  'think': 19,
#  'so.': 12,
#  'Cassius;': 5,
#  'well,': 6,
#  'here': 25,
#  'so': 67,
#  'long?': 1,
#  'impart': 1,
#  'aught': 2,
#  'toward': 3,
#  'general': 6,
#  'good,': 1,
#  'honour': 8,
#  'one': 24,
#  'death': 10,
#  'iâ€™': 2,
#  'other,': 1,
#  'both': 6,
#  'indifferently;': 1,
#  'speed': 2,
#  'name': 10,
#  'virtue': 6,
#  'outward': 1,
#  'favour.': 2,
#  'Well,': 4,
#  'subject': 1,
#  'story.': 1,
#  'tell': 30,
#  'Think': 3,
#  'life;': 1,
#  'single': 1,
#  'self,': 2,
#  'lief': 1,
#  'In': 22,
#  'awe': 2,
#  'thing': 6,
#  'born': 2,
#  'free': 3,
#  'were': 34,
#  'you;': 11,
#  'We': 12,
#  'fed': 1,
#  'Endure': 1,
#  'winterâ€™s': 1,
#  'cold': 6,
#  'he:': 1,
#  'once,': 5,
#  'raw': 2,
#  'gusty': 1,
#  'day,': 4,
#  'troubled': 1,
#  'chafing': 1,
#  'shores,': 1,
#  'said': 5,
#  'â€œDarâ€™st': 1,
#  'thou,': 4,
#  'Leap': 1,
#  'angry': 4,
#  'flood,': 3,
#  'swim': 2,
#  'yonder': 2,
#  'point?â€\x9d': 1,
#  'word,': 6,
#  'Accoutred': 1,
#  'was,': 3,
#  'plunged': 1,
#  'in,': 4,
#  'bade': 4,
#  'follow:': 1,
#  'indeed': 2,
#  'did.': 2,
#  'torrent': 1,
#  'roarâ€™d,': 1,
#  'buffet': 1,
#  'With': 19,
#  'lusty': 2,
#  'sinews,': 1,
#  'throwing': 1,
#  'aside': 1,
#  'stemming': 1,
#  'hearts': 5,
#  'controversy.': 1,
#  'ere': 5,
#  'could': 17,
#  'arrive': 1,
#  'point': 4,
#  'proposâ€™d,': 1,
#  'cried,': 4,
#  'â€œHelp': 1,
#  'sink!â€\x9d': 1,
#  'Aeneas,': 1,
#  'ancestor,': 1,
#  'Did': 13,
#  'flames': 1,
#  'Troy': 1,
#  'shoulder': 1,
#  'Anchises': 1,
#  'bear,': 1,
#  'waves': 1,
#  'tired': 1,
#  'become': 3,
#  'god;': 1,
#  'wretched': 1,
#  'creature,': 1,
#  'bend': 2,
#  'body,': 4,
#  'carelessly': 1,
#  'nod': 1,
#  'fever': 1,
#  'Spain,': 1,
#  'fit': 4,
#  'mark': 7,
#  'How': 20,
#  'shake:': 2,
#  'â€™tis': 15,
#  'true,': 3,
#  'god': 1,
#  'His': 7,
#  'coward': 3,
#  'lips': 3,
#  'colour': 2,
#  'fly,': 3,
#  'whose': 2,
#  'world': 7,
#  'lose': 4,
#  'lustre.': 1,
#  'groan:': 1,
#  'his,': 1,
#  'Romans': 9,
#  'Mark': 26,
#  'him,': 25,
#  'write': 3,
#  'speeches': 1,
#  'books,': 1,
#  'Alas,': 5,
#  'â€œGive': 1,
#  'drink,': 1,
#  'Titinius,â€\x9d': 1,
#  'sick': 5,
#  'girl.': 1,
#  'Ye': 1,
#  'gods,': 11,
#  'amaze': 1,
#  'feeble': 4,
#  'temper': 1,
#  'should': 35,
#  'start': 2,
#  'majestic': 1,
#  'world,': 5,
#  'palm': 1,
#  'alone.': 2,
#  '[_Shout.': 1,
#  'Flourish._]': 1,
#  'shout?': 1,
#  'believe': 2,
#  'applauses': 1,
#  'honours': 5,
#  'heapâ€™d': 1,
#  'man,': 9,
#  'bestride': 1,
#  'narrow': 1,
#  'Like': 6,
#  'Colossus,': 1,
#  'petty': 1,
#  'Walk': 1,
#  'under': 6,
#  'huge': 3,
#  'legs,': 1,
#  'peep': 1,
#  'ourselves': 3,
#  'dishonourable': 1,
#  'graves.': 1,
#  'Men': 1,
#  'masters': 2,
#  'fates:': 1,
#  'fault,': 2,
#  'dear': 7,
#  'stars,': 2,
#  'ourselves,': 2,
#  'underlings.': 1,
#  'â€œBrutusâ€\x9d': 2,
#  'â€œCaesarâ€\x9d:': 1,
#  'â€œCaesarâ€\x9d?': 1,
#  'sounded': 1,
#  'yours?': 2,
#  'Write': 1,
#  'together,': 2,
#  'yours': 3,
#  'fair': 2,
#  'name;': 2,
#  'Sound': 1,
#  'them,': 7,
#  'mouth': 1,
#  'well;': 1,
#  'Weigh': 1,
#  'heavy;': 1,
#  'conjure': 1,
#  'â€™em,': 1,
#  'soon': 3,
#  'â€œCaesar.â€\x9d': 1,
#  'Now': 15,
#  'names': 2,
#  'meat': 1,
#  'feed,': 1,
#  'grown': 3,
#  'great?': 1,
#  'Age,': 1,
#  'shamâ€™d!': 1,
#  'hast': 13,
#  'lost': 2,
#  'breed': 2,
#  'bloods!': 1,
#  'went': 6,
#  'age': 2,
#  'famâ€™d': 1,
#  'man?': 2,
#  'now,': 14,
#  'talkâ€™d': 1,
#  'wide': 1,
#  'encompassâ€™d': 1,
#  'Rome': 13,
#  'enough,': 2,
#  'man.': 7,
#  'O,': 22,
#  'fathers': 1,
#  'There': 16,
#  'brookâ€™d': 1,
#  'Thâ€™': 3,
#  ...}

# %% [markdown]
# Now here is where the iterative nature of dictionaries can be used to our benefit. We sort the worddict, using the function `worddict.get` to provide the values, which are the counts.

# %%
topwords = sorted(worddict, key = worddict.get, reverse=True)

# %%
for word in topwords[:20]:
    print(word, worddict[word])
# Out:
# the 531
# I 499
# and 426
# of 356
# to 347
# you 265
# a 231
# is 214
# in 206
# And 201
# not 199
# BRUTUS. 193
# that 184
# my 169
# his 150
# CASSIUS. 138
# with 137
# he 135
# be 129
# have 125

# %% [markdown]
# You can even make a hacky histogram for this by creating a '#' for every 10 occurences

# %%
for word in topwords[:20]:
    print(word+(20 - len(word))*' ', (worddict[word]//10)*'*')
# Out:
# the                  *****************************************************
# I                    *************************************************
# and                  ******************************************
# of                   ***********************************
# to                   **********************************
# you                  **************************
# a                    ***********************
# is                   *********************
# in                   ********************
# And                  ********************
# not                  *******************
# BRUTUS.              *******************
# that                 ******************
# my                   ****************
# his                  ***************
# CASSIUS.             *************
# with                 *************
# he                   *************
# be                   ************
# have                 ************

# %% [markdown]
# ## EXERCISE 2: Simulate a Bank Account

# %%
class BankAccount:
    def __init__(self, balance):
        self.balance = balance
        
    def withdraw(self, amount):
        self.balance = self.balance - amount

# %%
myaccount = BankAccount(100)
print(myaccount.balance)
myaccount.withdraw(20)
myaccount.balance
# Out:
# 100
# 80

# %% [markdown]
# Python supports inheritance. Indeed, in python, all classes inherit from object, which means that they all get some attributes and methods from object.
#
# What is inheritance, more precisely? In inheritance an object is based on another object. When inheritance is implemented, the methods and attributes that were defined in the base class will also be present in the inherited class. This is generally done to abstract away similar code in multiple classes. The abstracted code will reside in the base class and the previous classes will now inherit from the base class.
#
# Let's look at an example of inheritance. In the following example, Rocket is the base class and MarsRover is the inherited class. Notice the string interpolation in the formatting as well.

# %%
class Rocket:
    def __init__(self, name, distance):
        self.name = name
        self.distance = distance
 
    def launch(self):
        return "%s has reached %s" % (self.name, self.distance)
    
    def get_maker(self):
        return "%s Launched" % self.name
 
 
class MarsRover(Rocket): # inheriting from the base class
    def __init__(self, name, distance, maker):
        Rocket.__init__(self, name, distance)
        self.maker = maker
 
    def get_maker(self):
        return "%s Launched by %s" % (self.name, self.maker)

# %%
x = Rocket("Simple rocket", "till stratosphere")
y = MarsRover("Mangalyaan", "till Mars", "ISRO")
print(x.launch())
print(y.launch()) # dispatches to Ricket's launch
print(x.get_maker())
print(y.get_maker())
# Out:
# Simple rocket has reached till stratosphere
# Mangalyaan has reached till Mars
# Simple rocket Launched
# Mangalyaan Launched by ISRO

# %% [markdown]
# `launch` is not defined by the derived class `MarsRover` so the `launch` for instance `y` is used from `Rocket`. On the other hand, `MarsRover` defines a new `get_maker` so that overrides the one from `Rocket`. Thus inheritance can be used to share functionality when needed and diversify when not.

# %% [markdown]
# Define an error checking bank account `ECBankAccount` which inherits from `BankAccount` but will not allow overdraws. If there is an overdraw raise a `ValueError` with a message "Withdrawal Not Allowed": read up on this. Create two accounts one regular and one he derived class instance and wihdraw more than the balance from both.

# %%
# your code here
class ECBankAccount:
    def __init__(self, balance):
       BankAccount.__init__(self, balance)
    def withdraw(self, amount):
        check = self.balance - amount
        if check >=0:
            self.balance -= amount
        else:
            raise ValueError("Withdrawal Not Allowed")

# %%
x = BankAccount(100)
x.withdraw(120)
x.balance
# Out:
# -20

# %%
y = ECBankAccount(100)
y.withdraw(120)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-a76b103400b5> in <module>()
#       1 y = ECBankAccount(100)
# ----> 2 y.withdraw(120)
#
# <ipython-input-37-8fac68ea622b> in withdraw(self, amount)
#       8             self.balance -= amount
#       9         else:
# ---> 10             raise ValueError("Withdrawal Not Allowed")
#
# ValueError: Withdrawal Not Allowed

# %%
y.balance
# Out:
# 100
